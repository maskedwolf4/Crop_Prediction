# %% [markdown]
# # Cleaning Data

# %%
# importing libraries

import numpy as np
import pandas as pd
import config

# %%
# loading data

df=pd.read_csv("config.TRAINING_PATH")

df.head()
# Out:
#    Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 0        90          42         43    20.879744  82.002744  6.502985
# 1        85          58         41    21.770462  80.319644  7.038096
# 2        60          55         44    23.004459  82.320763  7.840207
# 3        74          35         40    26.491096  80.158363  6.980401
# 4        78          42         42    20.130175  81.604873  7.628473
#
#      Rainfall  Crop
# 0  202.935536  Rice
# 1  226.655537  Rice
# 2  263.964248  Rice
# 3  242.864034  Rice
# 4  262.717340  Rice

# %%
df.describe()
# Out:
#           Nitrogen   Phosphorus    Potassium  Temperature     Humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#           pH_Value     Rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
#checking NaN values

df.isna().sum()
# Out:
# Nitrogen       0
# Phosphorus     0
# Potassium      0
# Temperature    0
# Humidity       0
# pH_Value       0
# Rainfall       0
# Crop           0
# dtype: int64

# %%
# lets check unique crops 

crp=df['Crop'].unique()

print(crp)
# Out:
# ['Rice' 'Maize' 'ChickPea' 'KidneyBeans' 'PigeonPeas' 'MothBeans'
#  'MungBean' 'Blackgram' 'Lentil' 'Pomegranate' 'Banana' 'Mango' 'Grapes'
#  'Watermelon' 'Muskmelon' 'Apple' 'Orange' 'Papaya' 'Coconut' 'Cotton'
#  'Jute' 'Coffee']

# %%
# factorizing crop values

df['Crop'] = pd.factorize(df['Crop'])[0] + 1

df.head()
# Out:
#    Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 0        90          42         43    20.879744  82.002744  6.502985
# 1        85          58         41    21.770462  80.319644  7.038096
# 2        60          55         44    23.004459  82.320763  7.840207
# 3        74          35         40    26.491096  80.158363  6.980401
# 4        78          42         42    20.130175  81.604873  7.628473
#
#      Rainfall  Crop
# 0  202.935536     1
# 1  226.655537     1
# 2  263.964248     1
# 3  242.864034     1
# 4  262.717340     1

# %%
# checking number of unique crops

crp_len=df['Crop'].unique()

print(len(crp_len))
# Out:
# 22

# %% [markdown]
# We have 22 number of crops

# %% [markdown]
# With our data meticulously cleaned, we're all set to embark on the insightful journey of exploratory data analysis (EDA) to uncover hidden patterns and stories within in the data inside exploration.ipynb file
